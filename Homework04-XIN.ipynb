# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#### I use three models to modify, and the RandomForestClassifier have the best accuracy with the same random state

# %%
data = pd.read_csv("./glass.csv")
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
target = data['Type']
glass = data.iloc[:,0:9]
glass
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
#####################DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(glass, target, test_size=0.2, random_state=42)

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7209302325581395

# %%
#######################LogisticRegression
from sklearn.linear_model import LogisticRegression
X_train, X_test, y_train, y_test = train_test_split(glass, target, test_size=0.2, random_state=42)

model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)


######Have covergence problem , so not good
# Out:
# Accuracy: 0.7209302325581395
# /home/xin/miniconda3/envs/qm-tur/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
##################RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(glass, target, test_size=0.2, random_state=42)

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8372093023255814

# %%
###plot

import matplotlib.pyplot as plt

fig, axs = plt.subplots(4, 2, figsize=(8, 16))

ax1 = axs[0, 0]
ax2 = axs[0, 1]
ax3 = axs[1, 0]
ax4 = axs[1, 1]
ax5 = axs[2, 0]
ax6 = axs[2, 1]
ax7 = axs[3, 0]
ax8 = axs[3, 1]

# Subplot 1: Na vs. RI
ax1.scatter(X_test['RI'], X_test['Na'], c=y_pred, cmap='hot')
ax1.set_xlabel('RI')
ax1.set_ylabel('Na')
ax1.set_title('Classification Results for Na')

# Subplot 2: Mg vs. RI
ax2.scatter(X_test['RI'], X_test['Mg'], c=y_pred, cmap='hot')
ax2.set_xlabel('RI')
ax2.set_ylabel('Mg')
ax2.set_title('Classification Results for Mg')

# Subplot 3: Al vs. RI
ax3.scatter(X_test['RI'], X_test['Al'], c=y_pred, cmap='hot')
ax3.set_xlabel('RI')
ax3.set_ylabel('Al')
ax3.set_title('Classification Results for Al')

# Subplot 4: Si vs. RI
ax4.scatter(X_test['RI'], X_test['Si'], c=y_pred, cmap='hot')
ax4.set_xlabel('RI')
ax4.set_ylabel('Si')
ax4.set_title('Classification Results for Si')

# Subplot 5: K vs. RI
ax5.scatter(X_test['RI'], X_test['K'], c=y_pred, cmap='hot')
ax5.set_xlabel('RI')
ax5.set_ylabel('K')
ax5.set_title('Classification Results for K')

# Subplot 6: Ca vs. RI
ax6.scatter(X_test['RI'], X_test['Ca'], c=y_pred, cmap='hot')
ax6.set_xlabel('RI')
ax6.set_ylabel('Ca')
ax6.set_title('Classification Results for Ca')

# Subplot 7: Ba vs. RI
ax7.scatter(X_test['RI'], X_test['Ba'], c=y_pred, cmap='hot')
ax7.set_xlabel('RI')
ax7.set_ylabel('Ba')
ax7.set_title('Classification Results for Ba')

# Subplot 8: Fe vs. RI
ax8.scatter(X_test['RI'], X_test['Fe'], c=y_pred, cmap='hot')
ax8.set_xlabel('RI')
ax8.set_ylabel('Fe')
ax8.set_title('Classification Results for Fe')

# Adjust spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()
